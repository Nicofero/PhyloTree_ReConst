# %% [markdown]
# # **Benchmarking metrics**
#
# After obtaining the RF distances between every reconstructed tree and its ground truth, we can now represent the obtained results to see how the method works.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import numpy as np
from collections import defaultdict

# %% [markdown]
# # **RF-Distance**

# %% [markdown]
# We have 3 distance datasets for every specie, so to save them we will use a dictionary.

# %%
# Initialization
bos_taurus = {}
homo_sapiens = {}
penicillium_digitatum = {}
puccinia_graminis = {}
schizosaccharomyces_pombe = {}
all_species = [bos_taurus, homo_sapiens, penicillium_digitatum, puccinia_graminis, schizosaccharomyces_pombe]
methods = ['qa', 'qa_adv2', 'hy', 'qaoa', 'qrao', 'pce']
species_names = ['Bos_taurus','Homo_sapiens','Puccinia_graminis','Penicillium_digitatum','Schizosaccharomyces_pombe']

for i,specie in enumerate(all_species):
    for method in methods:
        specie[method] = pd.read_csv(f'./{species_names[i]}/nmcut{method}_RF-distance.csv')

bos_taurus['qa'].head()
# Out:
#    size  branch_length                       id     RF
# 0    14         0.5387  0-5387_Phy0001ZSJ_BOVIN  18.18
# 1    19         0.5800  0-5800_Phy0001WOF_BOVIN  25.00
# 2    12         0.6610  0-6610_Phy001QA4Q_BOVIN  11.11
# 3    33         0.6264  0-6264_Phy00025XU_BOVIN  20.00
# 4    16         0.2940  0-2940_Phy0001SHY_BOVIN  38.46

# %% [markdown]
# Let's start by just making comparisons for each species individually.
#
# ## **Bos Taurus**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))
colors = [
    '#0066FF',  # vivid blue
    '#FF9500',  # vivid orange
    '#00C853',  # vivid green
    '#FF3D00',  # vivid red-orange
    '#E040FB',  # vivid purple
    '#FFEA00',  # vivid yellow
]

shape = [
    's',  # square
    'o',  # circle    
    'D',  # diamond
    '^',  # triangle up
    'v',  # triangle down
    'P',  # filled plus
]

for i, method in enumerate(methods):
    plt.scatter(bos_taurus[method]['size'], bos_taurus[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(bos_taurus[method]['branch_length'], bos_taurus[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Homo Sapiens**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(homo_sapiens[method]['size'], homo_sapiens[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(homo_sapiens[method]['branch_length'], homo_sapiens[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Penicillium Digitatum**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(penicillium_digitatum[method]['size'], penicillium_digitatum[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(penicillium_digitatum[method]['branch_length'], penicillium_digitatum[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Puccinia graminis**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(puccinia_graminis[method]['size'], puccinia_graminis[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(puccinia_graminis[method]['branch_length'], puccinia_graminis[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Schizosaccharomyces Pombe**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(schizosaccharomyces_pombe[method]['size'], schizosaccharomyces_pombe[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(schizosaccharomyces_pombe[method]['branch_length'], schizosaccharomyces_pombe[method]['RF'],edgecolor='k', s=150, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Multiple scatterplots
#
# Now we are going to create a mosaic with all scatterplots together.

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['RF'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %%
mosaic = """
AB
CE
DD
"""

fig, axes = plt.subplot_mosaic(
    mosaic,
    figsize=(20, 14),
    sharex=True,
    sharey=True
)

panel_keys = ['A', 'B', 'C', 'D', 'E']

# Plot each species
for key, species, name in zip(panel_keys, all_species, species_names):
    ax = axes[key]

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['RF'],
            edgecolor='k',
            s=110 if key == 'E' else 90,  # bigger markers for the large panel
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=20 if key == 'E' else 16)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Global labels
fig.supxlabel('Number of sequences', fontsize=26)
fig.supylabel('% of correctly recovered branches', fontsize=26)

# Global legend
handles, labels = axes['A'].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)

for ax in axes.values():
    ax.set_xlim(9, 41)
    ax.set_ylim(-5, 105)

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
all_means = defaultdict(list)
for i,specie in enumerate(all_species):
    for method in methods:
        all_means[method].append(specie[method]["RF"].mean())
        print(f'{method} average RF for {species_names[i]}: {specie[method]["RF"].mean():.2f}')
        print(f'{method} max RF for {species_names[i]}: {specie[method]["RF"].max():.2f}')
        print(f'{method} min RF for {species_names[i]}: {specie[method]["RF"].min():.2f}\n')

    print('-------------------------------\n')
    
for key in all_means.keys():
    print(f'For method {key} the mean RF is {round(np.array(all_means[key]).mean(),2)}')
# Out:
# qa average RF for Bos_taurus: 28.84
# qa max RF for Bos_taurus: 87.50
# qa min RF for Bos_taurus: 2.94
#
# qa_adv2 average RF for Bos_taurus: 28.33
# qa_adv2 max RF for Bos_taurus: 75.00
# qa_adv2 min RF for Bos_taurus: 6.67
#
# hy average RF for Bos_taurus: 47.05
# hy max RF for Bos_taurus: 81.25
# hy min RF for Bos_taurus: 18.18
#
# qaoa average RF for Bos_taurus: 8.75
# qaoa max RF for Bos_taurus: 37.50
# qaoa min RF for Bos_taurus: 0.00
#
# qrao average RF for Bos_taurus: 36.32
# qrao max RF for Bos_taurus: 84.62
# qrao min RF for Bos_taurus: 0.00
#
# pce average RF for Bos_taurus: 7.26
# pce max RF for Bos_taurus: 28.57
# pce min RF for Bos_taurus: 0.00
#
# -------------------------------
#
# qa average RF for Homo_sapiens: 29.99
# qa max RF for Homo_sapiens: 88.89
# qa min RF for Homo_sapiens: 8.11
#
# qa_adv2 average RF for Homo_sapiens: 24.29
# qa_adv2 max RF for Homo_sapiens: 88.89
# qa_adv2 min RF for Homo_sapiens: 3.03
#
# hy average RF for Homo_sapiens: 53.20
# ...

# %%
# Scatter plot with every method for every specie
plt.figure(figsize=(16, 8))

for s, dataset in enumerate(all_species):
    for i, method in enumerate(methods):
        plt.scatter(
            dataset[method]['branch_length'],
            dataset[method]['RF'],
            edgecolor='k',            
            s=75,
            c=colors[i],
            marker=shape[i],
            label=method if s == 0 else None
        )

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for every specie (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method for every specie
plt.figure(figsize=(16, 8))

for s, dataset in enumerate(all_species):
    for i, method in enumerate(methods):
        plt.scatter(
            dataset[method]['size'],
            dataset[method]['RF'],
            edgecolor='k',
            s=75,
            c=colors[i],
            marker=shape[i],
            label=method if s == 0 else None
        )

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for every specie', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# We have the same conclusions that we had before, for the quantum methods it exists a clear downward tendency as the number of sequences grows. This is true for both advantage versions. However this downward tendency doesn't appears in the hybrid approach meaning it has to do with the nature of the quantum methods. It probably has something to do with the way the embeddings with in the Advantage QPU.
#
# The branch size, as i suspected before, doesn't make a difference for the precision. It seems that the precision is independent from the branch length, however it seems to begin to grow when it is large. Though I don't have enough data to confirm this theory, specially for the QPU methods.

# %% [markdown]
# # **Clustering distance**
#
# We are going to repeat the analysis we did with the RF distance with the clustering distance. This type of distance doesn't only incorporate the idea of obtaining identical clades, but how close the failed clades are from each
# other.

# %%
# Initialization
bos_taurus_clust = {}
homo_sapiens_clust = {}
penicillium_digitatum_clust = {}
puccinia_graminis_clust = {}
schizosaccharomyces_pombe_clust = {}
all_species_clust = [bos_taurus_clust, homo_sapiens_clust, penicillium_digitatum_clust, puccinia_graminis_clust, schizosaccharomyces_pombe_clust]
methods = ['qa', 'qa_adv2', 'hy', 'qaoa','qrao','pce']
species_names = ['Bos_taurus','Homo_sapiens','Puccinia_graminis','Penicillium_digitatum','Schizosaccharomyces_pombe']

for i,specie in enumerate(all_species_clust):
    for method in methods:
        specie[method] = pd.read_csv(f'./{species_names[i]}/nmcut{method}_clust-distance.csv')

bos_taurus_clust['qa'].head()
# Out:
#    size  branch_length                       id  clustering_distance
# 0    14         0.5387  0-5387_Phy0001ZSJ_BOVIN             0.433413
# 1    19         0.5800  0-5800_Phy0001WOF_BOVIN             0.526580
# 2    12         0.6610  0-6610_Phy001QA4Q_BOVIN             0.374822
# 3    33         0.6264  0-6264_Phy00025XU_BOVIN             0.427749
# 4    16         0.2940  0-2940_Phy0001SHY_BOVIN             0.481463

# %% [markdown]
# Let's start by just making comparisons for each species individually.
#
# ## **Bos Taurus**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(bos_taurus_clust[method]['size'], bos_taurus_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(bos_taurus_clust[method]['branch_length'], bos_taurus_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Homo Sapiens**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(homo_sapiens_clust[method]['size'], homo_sapiens_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(homo_sapiens_clust[method]['branch_length'], homo_sapiens_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens (by branch length)', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Penicillium Digitatum**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(penicillium_digitatum_clust[method]['size'], penicillium_digitatum_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(penicillium_digitatum_clust[method]['branch_length'], penicillium_digitatum_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Puccinia Graminis**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(puccinia_graminis_clust[method]['size'], puccinia_graminis_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(puccinia_graminis_clust[method]['branch_length'], puccinia_graminis_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **Schizosaccharomyces Pombe**

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(schizosaccharomyces_pombe_clust[method]['size'], schizosaccharomyces_pombe_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    plt.scatter(schizosaccharomyces_pombe_clust[method]['branch_length'], schizosaccharomyces_pombe_clust[method]['clustering_distance'],edgecolor='k', s=100, label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe (by branch length)', fontsize=25)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## **All together**

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %%
all_means = defaultdict(list)
for i,specie in enumerate(all_species_clust):
    for method in methods:
        all_means[method].append(specie[method]["clustering_distance"].mean())
        print(f'{method} average clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].mean():.4f}')
        print(f'{method} max clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].max():.4f}')
        print(f'{method} min clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].min():.4f}\n')

    print('-------------------------------\n')

for key in all_means.keys():
    print(f'For method {key} the mean clustering distance is {round(np.array(all_means[key]).mean(),4)}')
# Out:
# qa average clustering distance for Bos_taurus: 0.5009
# qa max clustering distance for Bos_taurus: 0.8620
# qa min clustering distance for Bos_taurus: 0.3009
#
# qa_adv2 average clustering distance for Bos_taurus: 0.4942
# qa_adv2 max clustering distance for Bos_taurus: 0.7746
# qa_adv2 min clustering distance for Bos_taurus: 0.2200
#
# hy average clustering distance for Bos_taurus: 0.6474
# hy max clustering distance for Bos_taurus: 0.8702
# hy min clustering distance for Bos_taurus: 0.4150
#
# qaoa average clustering distance for Bos_taurus: 0.3086
# qaoa max clustering distance for Bos_taurus: 0.6235
# qaoa min clustering distance for Bos_taurus: 0.1360
#
# qrao average clustering distance for Bos_taurus: 0.5782
# qrao max clustering distance for Bos_taurus: 0.8961
# qrao min clustering distance for Bos_taurus: 0.3389
#
# pce average clustering distance for Bos_taurus: 0.2882
# pce max clustering distance for Bos_taurus: 0.5195
# pce min clustering distance for Bos_taurus: 0.1665
# ...

# %% [markdown]
# # **Comparison between RF and Clustering distances**

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=1,
    ncols=2,
    figsize=(20, 10),
    sharex=True,
    sharey=False
)

for i, method in enumerate(methods):
    axes[0].scatter(
        bos_taurus[method]['size'],
        bos_taurus[method]['RF']/100,
        edgecolor='k',
        s=100,
        c=colors[i],
        marker=shape[i],
        label=method
    )
    axes[0].set_title('RF-distance', fontsize=18)
    axes[0].xaxis.set_major_locator(ticker.MultipleLocator(5))
    axes[0].yaxis.set_major_locator(ticker.MultipleLocator(0.1))
    axes[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
    axes[0].xaxis.set_minor_locator(ticker.MultipleLocator(1))

    # Style the minor grid differently (lighter/thinner)
    axes[0].grid(which='minor', linestyle=':', alpha=0.3)
    
    axes[0].grid(which='major', alpha=0.5)
    
for i, method in enumerate(methods):
    axes[1].scatter(
        bos_taurus_clust[method]['size'],
        bos_taurus_clust[method]['clustering_distance'],
        edgecolor='k',
        s=100,
        c=colors[i],
        marker=shape[i],
        label=method
    )
    axes[1].set_title('Clustering-distance', fontsize=18)
    # And a corresponding grid
    axes[1].xaxis.set_major_locator(ticker.MultipleLocator(5))
    axes[1].yaxis.set_major_locator(ticker.MultipleLocator(0.1))
    axes[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
    axes[1].xaxis.set_minor_locator(ticker.MultipleLocator(1))

    # Style the minor grid differently (lighter/thinner)
    axes[1].grid(which='minor', linestyle=':', alpha=0.3)    
    
    axes[1].grid(which='major', alpha=0.5)
    

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)


axes[0].set_xlim(9, 41)
axes[1].set_xlim(9, 41)

axes[0].set_ylim(-0.05, 1.05)
axes[1].set_ylim(-0.05, 1.05)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=1,
    ncols=2,
    figsize=(20, 10),
    sharex=True,
    sharey=False
)

for i, method in enumerate(methods):
    axes[0].scatter(
        homo_sapiens[method]['size'],
        homo_sapiens[method]['RF']/100,
        edgecolor='k',
        s=100,
        c=colors[i],
        marker=shape[i],
        label=method
    )
    axes[0].set_title('RF-distance', fontsize=18)
    axes[0].xaxis.set_major_locator(ticker.MultipleLocator(5))
    axes[0].yaxis.set_major_locator(ticker.MultipleLocator(0.1))
    axes[0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
    axes[0].xaxis.set_minor_locator(ticker.MultipleLocator(1))

    # Style the minor grid differently (lighter/thinner)
    axes[0].grid(which='minor', linestyle=':', alpha=0.3)
    
    axes[0].grid(which='major', alpha=0.5)
    
for i, method in enumerate(methods):
    axes[1].scatter(
        homo_sapiens_clust[method]['size'],
        homo_sapiens_clust[method]['clustering_distance'],
        edgecolor='k',
        s=100,
        c=colors[i],
        marker=shape[i],
        label=method
    )
    axes[1].set_title('Clustering-distance', fontsize=18)
    # And a corresponding grid
    axes[1].xaxis.set_major_locator(ticker.MultipleLocator(5))
    axes[1].yaxis.set_major_locator(ticker.MultipleLocator(0.1))
    axes[1].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
    axes[1].xaxis.set_minor_locator(ticker.MultipleLocator(1))

    # Style the minor grid differently (lighter/thinner)
    axes[1].grid(which='minor', linestyle=':', alpha=0.3)    
    
    axes[1].grid(which='major', alpha=0.5)
    

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)


axes[0].set_xlim(9, 41)
axes[1].set_xlim(9, 41)

axes[0].set_ylim(-0.05, 1.05)
axes[1].set_ylim(-0.05, 1.05)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %% [markdown]
# # **Time**
#
# I have time data for the methods, however, for the hybrid version, the time is irrelevant as it operates using a max time of computation and then yields the best result after that time, thus meaning the time it takes to create one tree is $\max_{time}\cdot N_{probs}$. It does make sense to compare for the QPU methods, so we can do that.

# %%
# Initialization
bos_taurus_time = {}
homo_sapiens_time = {}
penicillium_digitatum_time = {}
puccinia_graminis_time = {}
schizosaccharomyces_pombe_time = {}
all_species_time = [bos_taurus_time, homo_sapiens_time, penicillium_digitatum_time, puccinia_graminis_time, schizosaccharomyces_pombe_time]
methods = ['', '_adv2']
species_names = ['Bos_taurus','Homo_sapiens','Puccinia_graminis','Penicillium_digitatum','Schizosaccharomyces_pombe']

for i,specie in enumerate(all_species_time):
    for method in methods:
        specie[method] = pd.read_csv(f'./{species_names[i]}/timer{method}_{species_names[i]}.csv')

bos_taurus_time[''].head()
# Out:
#    size                                name   method        time
# 0    19  0-2516_Phy0001SS5_BOVIN_matrix.txt  NMcutQA   680.19208
# 1    16  0-2653_Phy0001SSU_BOVIN_matrix.txt  NMcutQA   607.18656
# 2    36  0-2536_Phy0001SML_BOVIN_matrix.txt  NMcutQA  2310.11820
# 3    26  0-2659_Phy0001SUZ_BOVIN_matrix.txt  NMcutQA  1152.05356
# 4    26  0-2876_Phy0001SON_BOVIN_matrix.txt  NMcutQA  1483.97984

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_time, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['time']/1000,
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label= method if method != '' else 'adv1'
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('Time (s)', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='upper center',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %% [markdown]
# ## Decreasing tendency
#
# Let's check the decreasing tendency of the similarity by averaging the similarities between trees for each taxa.

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
methods = ['qa', 'qa_adv2', 'hy', 'qaoa', 'qrao', 'pce']
# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = bos_taurus[method].groupby('size',as_index=False)['RF'].mean()
    df_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['RF_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = bos_taurus_clust[method].groupby('size',as_index=False)['clustering_distance'].mean()
    df_by_taxa.rename(columns={'clustering_distance':'clustering_distance_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['clustering_distance_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Bos Taurus', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ---

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = homo_sapiens[method].groupby('size',as_index=False)['RF'].mean()
    df_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['RF_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = homo_sapiens_clust[method].groupby('size',as_index=False)['clustering_distance'].mean()
    df_by_taxa.rename(columns={'clustering_distance':'clustering_distance_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['clustering_distance_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Homo Sapiens', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ---

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = penicillium_digitatum[method].groupby('size',as_index=False)['RF'].mean()
    df_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['RF_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = penicillium_digitatum_clust[method].groupby('size',as_index=False)['clustering_distance'].mean()
    df_by_taxa.rename(columns={'clustering_distance':'clustering_distance_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['clustering_distance_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Penicillium Digitatum', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ---

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = puccinia_graminis[method].groupby('size',as_index=False)['RF'].mean()
    df_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['RF_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = puccinia_graminis_clust[method].groupby('size',as_index=False)['clustering_distance'].mean()
    df_by_taxa.rename(columns={'clustering_distance':'clustering_distance_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['clustering_distance_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Puccinia Graminis', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ---

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = schizosaccharomyces_pombe[method].groupby('size',as_index=False)['RF'].mean()
    df_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['RF_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %%
# bos_taurus_by_taxa = bos_taurus.groupby('size',as_index=False)['RF'].mean()
# bos_taurus_by_taxa.rename(columns={'RF':'RF_mean'},inplace=True)

# Scatter plot with every method
plt.figure(figsize=(16, 8))

for i, method in enumerate(methods):
    df_by_taxa = schizosaccharomyces_pombe_clust[method].groupby('size',as_index=False)['clustering_distance'].mean()
    df_by_taxa.rename(columns={'clustering_distance':'clustering_distance_mean'},inplace=True)
    plt.plot(df_by_taxa['size'], df_by_taxa['clustering_distance_mean'], label=f'{method}', c=colors[i],marker=shape[i])

plt.xlabel('Number of sequences',fontdict={'fontsize': 20})
plt.ylabel('% of correctly recovered branches',fontdict={'fontsize': 20})
plt.title('Comparison between methods for Schizosaccharomyces Pombe', fontsize=30)
plt.grid(color='gray', linestyle='--', linewidth=0.4)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # More specific comparisons
#
# After making a full comparison of all the methods, and as seen that it is difficult to see anything on the graphs, I want to have a more specific and clear comparison, for example:
#
# - Comparison on QA-based approaches
# - Comparison on gates-based approaches
# - Comparison of QA with SA
# - Comparison of QRAO ansatzs
# - Comparison of sparsity method on PCE
# - Comparison of generated trees

# %%
all_species_clust = [bos_taurus_clust, homo_sapiens_clust, penicillium_digitatum_clust, puccinia_graminis_clust, schizosaccharomyces_pombe_clust]
methods = ['qa', 'qa_adv2', 'hy', 'qaoa','qrao','pce', 'qrao_esu2', 'spce', 'sa', 'nj']
species_names = ['Bos_taurus','Homo_sapiens','Puccinia_graminis','Penicillium_digitatum','Schizosaccharomyces_pombe']

for i,specie in enumerate(all_species_clust):
    for method in methods:
        specie[method] = pd.read_csv(f'./{species_names[i]}/nmcut{method}_clust-distance.csv')

# %% [markdown]
# ## QA-based approaches

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()
methods = ['qa', 'qa_adv2', 'hy']

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower right',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gates-based approach

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()
methods = ['qaoa', 'qrao', 'pce']

all_species_clust_reduced = []

for specie in all_species_clust:
    reduced = {}
    for method in methods:
        df = specie[method]
        reduced[method] = df.loc[df['size'] <= 25].copy()
    all_species_clust_reduced.append(reduced)

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust_reduced, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower right',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison of QA with a classical method

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)
axes = axes.flatten()
methods = ['nj', 'sa', 'hy', 'qa']

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower right',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison between QRAO ansatzs

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

bos_taurus_clust['qa'].head()

axes = axes.flatten()
methods = ['qrao', 'qrao_esu2']

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower right',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout()
plt.show()

# %%
all_means = defaultdict(list)
for i,specie in enumerate(all_species_clust):
    for method in methods:
        all_means[method].append(specie[method]["clustering_distance"].mean())
        print(f'{method} average clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].mean():.4f}')
        print(f'{method} max clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].max():.4f}')
        print(f'{method} min clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].min():.4f}\n')

    print('-------------------------------\n')

for key in all_means.keys():
    print(f'For method {key} the mean clustering distance is {round(np.array(all_means[key]).mean(),4)}')
# Out:
# qrao average clustering distance for Bos_taurus: 0.5782
# qrao max clustering distance for Bos_taurus: 0.8961
# qrao min clustering distance for Bos_taurus: 0.3389
#
# qrao_esu2 average clustering distance for Bos_taurus: 0.5510
# qrao_esu2 max clustering distance for Bos_taurus: 0.7764
# qrao_esu2 min clustering distance for Bos_taurus: 0.2762
#
# -------------------------------
#
# qrao average clustering distance for Homo_sapiens: 0.5620
# qrao max clustering distance for Homo_sapiens: 0.7378
# qrao min clustering distance for Homo_sapiens: 0.3751
#
# qrao_esu2 average clustering distance for Homo_sapiens: 0.5850
# qrao_esu2 max clustering distance for Homo_sapiens: 1.0000
# qrao_esu2 min clustering distance for Homo_sapiens: 0.4561
#
# -------------------------------
#
# qrao average clustering distance for Puccinia_graminis: 0.5894
# qrao max clustering distance for Puccinia_graminis: 0.8014
# qrao min clustering distance for Puccinia_graminis: 0.3305
#
# ...

# %% [markdown]
# # Comparison of sparsity method

# %%
# Create 2x3 grid
fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(20, 10),
    sharex=True,
    sharey=True
)

axes = axes.flatten()
methods = ['pce', 'spce']

all_species_clust_reduced = []

for specie in all_species_clust:
    reduced = {}
    for method in methods:
        df = specie[method]
        reduced[method] = df.loc[df['size'] <= 25].copy()
    all_species_clust_reduced.append(reduced)

# Plot only first 5 axes
for ax, species, name in zip(axes[:5], all_species_clust_reduced, species_names):

    for i, method in enumerate(methods):
        ax.scatter(
            species[method]['size'],
            species[method]['clustering_distance'],
            edgecolor='k',
            s=100,
            c=colors[i],
            marker=shape[i],
            label=method
        )

    ax.set_title(name, fontsize=18)
    ax.grid(color='gray', linestyle='--', linewidth=0.4)

# Hide unused subplot (bottom-right)
axes[5].axis('off')

# Global labels
fig.supxlabel('Number of sequences', fontsize=24)
fig.supylabel('% of correctly recovered branches', fontsize=24)

# One global legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower right',
    ncol=len(methods),
    fontsize=20
)

plt.tight_layout()
plt.show()

# %%
all_means = defaultdict(list)
for i,specie in enumerate(all_species_clust):
    for method in methods:
        all_means[method].append(specie[method]["clustering_distance"].mean())
        print(f'{method} average clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].mean():.4f}')
        print(f'{method} max clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].max():.4f}')
        print(f'{method} min clustering distance for {species_names[i]}: {specie[method]["clustering_distance"].min():.4f}\n')

    print('-------------------------------\n')

for key in all_means.keys():
    print(f'For method {key} the mean clustering distance is {round(np.array(all_means[key]).mean(),4)}')
# Out:
# pce average clustering distance for Bos_taurus: 0.2882
# pce max clustering distance for Bos_taurus: 0.5195
# pce min clustering distance for Bos_taurus: 0.1665
#
# spce average clustering distance for Bos_taurus: 0.2813
# spce max clustering distance for Bos_taurus: 0.5195
# spce min clustering distance for Bos_taurus: 0.1743
#
# -------------------------------
#
# pce average clustering distance for Homo_sapiens: 0.2413
# pce max clustering distance for Homo_sapiens: 0.3823
# pce min clustering distance for Homo_sapiens: 0.1285
#
# spce average clustering distance for Homo_sapiens: 0.2468
# spce max clustering distance for Homo_sapiens: 0.3977
# spce min clustering distance for Homo_sapiens: 0.1517
#
# -------------------------------
#
# pce average clustering distance for Puccinia_graminis: 0.2893
# pce max clustering distance for Puccinia_graminis: 0.5330
# pce min clustering distance for Puccinia_graminis: 0.1215
#
# ...

# %% [markdown]
# ## Drawing trees

# %%
from Bio import Phylo
import re
from io import StringIO

id = "0-2516_Phy0001SS5_BOVIN"
# get size from rf where id=id

with open(f'./Bos_taurus/{id}_nmcutqa_tree.txt','r') as file:
    qa_tree = file.read()
    
with open(f'../benchmarking matrices/Bos_taurus/{id}_tree.txt','r') as file:
    biotree = file.read()
    
with open(f'./Bos_taurus/{id}_nmcutqrao_tree.txt','r') as file:
    qiskit_tree = file.read()
    
biotree = re.sub(r'taxon([0-9]+)',lambda match: str(int(match.group(1)) - 1),biotree)
biotree = re.sub(r':[0-9]\.[0-9]+(e-[0-9]+)*',r'',biotree)
# print(biotree)

tree1 = Phylo.read(StringIO(qa_tree), "newick")
# Phylo.draw(tree1)
tree2 = Phylo.read(StringIO(biotree), "newick")
# Phylo.draw(tree2)
tree3 = Phylo.read(StringIO(qiskit_tree), "newick")


# Function to get clade terminal taxa sets by name
def get_clade_taxa_sets(tree):
    return {
        frozenset(term.name for term in clade.get_terminals()) 
        for clade in tree.find_clades() if len(clade.get_terminals()) > 1 and len(clade.get_terminals()) != 26  # Only internal clades
    }

# Find common clades based on their terminal taxa
common_taxa_sets = get_clade_taxa_sets(tree1).intersection(get_clade_taxa_sets(tree2))
common_taxa_sets_qaoa = get_clade_taxa_sets(tree3).intersection(get_clade_taxa_sets(tree2))

# Function to color branches with common taxa in red
def color_common_branches(tree, common_taxa_sets, color = "red"):
    for clade in tree.find_clades():
        # Only consider internal clades (with more than one terminal)
        if len(clade.get_terminals()) > 1:
            # Check if the clade's terminals match a common set
            if frozenset(term.name for term in clade.get_terminals()) in common_taxa_sets:
                clade.color = color
            else:
                clade.color = "black"  # Default color for non-common branches

# Color the branches in the first tree
color_common_branches(tree1, common_taxa_sets)
color_common_branches(tree3, common_taxa_sets_qaoa)

# Create a figure with subplots (side by side)
fig, (axes1, axes2, axes3) = plt.subplots(1, 3, figsize=(18, 9))

# Plot the second tree
Phylo.draw(tree2, do_show=False, axes=axes1)
axes1.set_title("Base tree",fontdict={'fontsize': 25})
plt.setp(axes1, xticks=[], yticks=[])  # Remove ticks
axes1.axis('off')  # Remove axes

# Plot the first tree
Phylo.draw(tree1, do_show=False, axes=axes2)
axes2.set_title("Tree generated by NMcutQA",fontdict={'fontsize': 25})
plt.setp(axes2, xticks=[], yticks=[])  # Remove ticks
axes2.axis('off')  # Remove axes

# Plot the third tree
Phylo.draw(tree3, do_show=False, axes=axes3)
axes3.set_title("Tree generated by NMcutQAOA",fontdict={'fontsize': 25})
plt.setp(axes3, xticks=[], yticks=[])  # Remove ticks
axes3.axis('off')  # Remove axes

# Show the plot
plt.tight_layout()
plt.show()
